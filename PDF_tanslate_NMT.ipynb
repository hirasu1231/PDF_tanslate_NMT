# %% [markdown]
# <a href="https://colab.research.google.com/gist/c-bata/67d72199474d3b0e3e7f9ecac6c6b11d/cuda-toolkit-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Python + BERTで英文のPDFをレイアウトを維持したまま翻訳してみる
# Python + BERTで英文のPDFをレイアウトを維持したままの翻訳を実施します．<br>
# 今回はGoogle ColabとGoogle Driveを連携させて，notebook形式で実行してます．<br>
#
# > Google Colaboratory（以下Google Colab）は、Google社が無料で提供している機械学習の教育や研究用の開発環境です。開発環境はJupyter Notebookに似たインターフェースを持ち、Pythonの主要なライブラリがプリインストールされています。<br>
# 引用元：[Google Colabの使い方](https://interface.cqpub.co.jp/ail01/)

# %% [markdown]
# ## Google Colabのファイル構成
# プロジェクトディレクトリはpdf_translate_bertとしています．度々，省略しています．
# ```init
# pdf_translate
# ├── /pdf_translate_bert
# │   ├── analyze_pdf_text_bert.py <- pdfの解析
# │   ├── translate_csv_bert.py <- 翻訳前後をcsv化
# │   ├── embed_annots.py <- pdfにコメ追加
# │   ├── pdf_translate_bert.sh <- 実行スクリプト
# │   ├── AttentionGAN.pdf <- 翻訳前
# │   ├── JA_BERT_AttentionGAN.pdf <- 翻訳後
# │   ├── AttentionGAN.pdf.bert.csv <- 翻訳前後csv
# │   ├── AttentionGAN.pdf.bert.json  <- pdf情報のjson
# │   └── (省略)
# └── pdf_translate_bert.ipynb <- 実行用ノートブック
# ```

# %% [markdown]
# ## Google Driveと連携
# Google ColabとGoogle Driveを連携させて，作業ディレクトリを作成します．<br>

# %%
# Google ColabとGoogle Driveを連携
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# # ディレクトリの移動
# cd /content/drive/My\ Drive/PDF_transrate
# # gitのダウンロード
# mkdir pdf_translate_bert
# ls
# Out:
# EasyNMT
# EasyNMT.ipynb
# PDF_tanslate.ipynb
# PDF_tanslate_NMT.ipynb
# pdf_translate
# pdf_translate_bert

# %%
# 作業ディレクトリの移動
# %cd /content/drive/My\ Drive/PDF_transrate/pdf_translate_bert
# !ls
# Out:
# /content/drive/My Drive/PDF_transrate/pdf_translate_bert
# 42_Russia		  AttentionGAN.pdf.bert.csv   JA_BERT_AttentionGAN.pdf
# 42_Russia_pdfs.csv	  AttentionGAN.pdf.bert.json  pdf_translate_bert.sh
# analyze_pdf_text_bert.py  book_pdf.pdf		      translate_csv_bert.py
# AttentionGAN.pdf	  embed_annots.py

# %% [markdown]
# ## モジュールのインストール
# 下記のコマンドでモジュールをインストールします．

# %%
# !pip install -U easynmt
# !pip install fitz
# !pip install PyMuPDF==1.16.14

# %% [markdown]
# ## 翻訳実行

# %% [markdown]
# ### コードの作成
# 個人的にcsvとして翻訳結果も残したいので，下記のコードを作成します．

# %%
# analyze_pdf_text_bert.pyの書き込み
# %%writefile analyze_pdf_text_bert.py

import sys
import fitz
import csv
import json
from tqdm import tqdm


def main(input_path):
    argvs = sys.argv
    argc = len(argvs)
    if argc != 2:
        print("Usage #python %s [PDFパス]" % argvs[0])
        exit()
    input_path = argvs[1]
    doc = fitz.open(input_path)
    list_string = []
    result = []
    pno = 0
    for page in tqdm(doc):
        blocklist = page.getText('blocks')
        for block in blocklist:
            r = fitz.Rect(block[0], block[1], block[2], block[3])
            txt = block[4].replace('\n', '').replace('\r', '')
            result.append({
                'page' : pno,
                'x0' : block[0],
                'y0' : block[1],
                'x1' : block[2],
                'y1' : block[3],
                'text' : txt,
                'block_type' : block[5],
                'block_no' : block[6],
            })
            if not txt in list_string:
                list_string.append(txt)
        pno += 1

    string_path = '{}.bert.csv'.format(input_path)
    with open(string_path, 'w', encoding='utf8', newline="") as fp:
        writer = csv.writer(fp)
        for s in list_string:
            writer.writerow([s, 'todo'])
    data = {
        "input_path" : input_path,
        "string_path" : string_path,
        "text_block" : result
    }
    with open('{}.bert.json'.format(input_path), mode='w', encoding='utf8') as fp:
        json.dump(data, fp, sort_keys=True, indent=4, ensure_ascii=False)


if __name__ == '__main__':
    main(sys.argv)
# Out:
# Writing analyze_pdf_text_bert.py

# %%
# translate_csv.pyの書き込み
# %%writefile translate_csv_bert.py

import sys
import time
import random
import pandas as pd
from easynmt import EasyNMT

# モデルの読み込み
model = EasyNMT('mbart50_m2m')

def main(input_path):
  argvs = sys.argv
  argc = len(argvs)
  if argc != 2:
      print("Usage #python %s [PDFãƒ‘ã‚¹]" % argvs[0])
      exit()
  input_path = argvs[1]
  df = pd.read_csv(input_path, names=('org_text', 'convert_text'))
  
  for i in range(len(df)):
      org_text = df['org_text'][i].replace('.', '. ')
      # print(org_text)
      df['convert_text'][i] = model.translate(org_text, target_lang='ja')
      
  df.to_csv(input_path, header=False, index=False)

if __name__ == '__main__':
  main(sys.argv)
# Out:
# Overwriting translate_csv_bert.py

# %%
# %%writefile embed_annots.py
import sys
import fitz
import csv
import json
from tqdm import tqdm


def main(argvs):
    """メイン処理"""
    argvs = sys.argv
    argc = len(argvs)
    if argc != 3:
        print("Usage #python %s [JSONパス] [出力パス]" % argvs[0])
        exit()
    json_path = argvs[1]
    out_path = argvs[2]
    with open(json_path, mode='r', encoding='utf8') as fp:
        json_info = json.load(fp)

    string_path = json_info['string_path']
    string_info = {}
    with open(string_path, 'r', encoding='utf8', newline="\n") as fp:
        reader = csv.reader(fp)
        for row in reader:
            string_info[row[0].strip()] = row[1]
    doc = fitz.open(json_info['input_path'])

    for text_block in tqdm(json_info["text_block"]):
        txt = text_block['text'].strip()
        if txt in string_info:
            txt = string_info[txt]
            # print(txt)
            page = doc[text_block['page']]
            page.addTextAnnot(
                (text_block['x1'] - 20, text_block['y1'] - 20),
                txt
            )
        else:
            print("翻訳に失敗：", text_block['text'])

    doc.save(out_path, garbage=1, clean=1, deflate=1) 

if __name__ == '__main__':
    main(sys.argv)
# Out:
# Overwriting embed_annots.py

# %% [markdown]
# ### シェルスクリプトファイルの作成
# 下記のコマンドでシェルスクリプトファイルの作成します．

# %%
# pdf_translate.shの書き込み
# %%writefile pdf_translate_bert.sh
#!/bin/sh
python ./analyze_pdf_text_bert.py "$1"
python ./translate_csv_bert.py "$1.bert.csv"
python ./embed_annots.py "$1.bert.json" "JA_BERT_$1"

rm "$1.bert.csv" "$1.bert.json"
# Out:
# Overwriting pdf_translate_bert.sh

# %% [markdown]
# ### 翻訳実行
# 下記のコマンドで翻訳を実行します．

# %%
# !ls
# Out:
# 42_Russia		  AttentionGAN.pdf.bert.csv   embed_annots.py
# 42_Russia_pdfs.csv	  AttentionGAN.pdf.bert.json  JA_BERT_AttentionGAN.pdf
# analyze_pdf_text_bert.py  book_pdf.pdf		      JA_BERT_book_pdf.pdf
# assembly64.pdf		  book_pdf.pdf.bert.csv       pdf_translate_bert.sh
# AttentionGAN.pdf	  book_pdf.pdf.bert.json      translate_csv_bert.py

# %%
# !sh pdf_translate_bert.sh assembly64.pdf
# Out:
# 100% 357/357 [00:00<00:00, 621.91it/s]
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
#  28% 1900/6707 [00:00<00:00, 18994.99it/s]翻訳に失敗： (gdb) x/5cb &strNum0x600104: 49 '1' 52 '4' 57 '9' 56 '8' 0 ''
# 100% 6707/6707 [00:00<00:00, 19519.79it/s]

# %%
# 42_Russia_translate.py
import subprocess
from glob import glob
import pandas as pd

ERROR_list = []
pdf_files = glob("./42_Russia/00_Projects/*/*/*.pdf")

df = pd.DataFrame(pdf_files, columns=['path'])
df.to_csv('42_Russia_pdfs.csv', index=False)

# %%
df = pd.read_csv('42_Russia_pdfs.csv')
pdf_files =df['path'].to_list()
pdf_files

# %%
# 42_Russia_translate.py
import subprocess
from glob import glob

ERROR_list = []
# pdf_files = glob("./42_Russia/00_Projects/*/*/*.pdf")
df = pd.read_csv('42_Russia_pdfs.csv')
pdf_files =df['path'].to_list()

# pdf_file = '../minishell_(new).pdf'

for pdf_file in pdf_files:
    try:
        # コマンド実行
        subprocess.run(["sh", "pdf_translate_bert.sh", pdf_file])
        print("END-",pdf_file)
    except:
        ERROR_list.append(pdf_file)
        print("ERROR-", pdf_file)
# Out:
# END- ./42_Russia/00_Projects/05_Infrastructure_and_Admin/00____init/init - scale for the project.pdf
# END- ./42_Russia/00_Projects/05_Infrastructure_and_Admin/00____init/init.pdf
# END- ./42_Russia/00_Projects/05_Infrastructure_and_Admin/ft_services/ft_services_Oct_08_20.pdf
# END- ./42_Russia/00_Projects/05_Infrastructure_and_Admin/04____roger-skyline-2/roger-skyline-2.pdf
# END- ./42_Russia/00_Projects/05_Infrastructure_and_Admin/03____roger-skyline-1/roger-skyline-1.pdf
# END- ./42_Russia/00_Projects/05_Infrastructure_and_Admin/ft_server/ft_server_03_17_2020_19:46.pdf
# END- ./42_Russia/00_Projects/05_Infrastructure_and_Admin/02____cloud-1/cloud-1_(new).pdf
# END- ./42_Russia/00_Projects/05_Infrastructure_and_Admin/02____cloud-1/cloud-1_(old).pdf
# END- ./42_Russia/00_Projects/05_Infrastructure_and_Admin/01____docker-1/docker-1.pdf
# END- ./42_Russia/00_Projects/09_OCaml/01____ft_turing/ft_turing.pdf
# END- ./42_Russia/00_Projects/09_OCaml/00____piscine_ocaml/d08.en.pdf
# END- ./42_Russia/00_Projects/09_OCaml/00____piscine_ocaml/d04.en.pdf
# END- ./42_Russia/00_Projects/09_OCaml/00____piscine_ocaml/d06.en.pdf
# END- ./42_Russia/00_Projects/09_OCaml/00____piscine_ocaml/d02.en.pdf
# END- ./42_Russia/00_Projects/09_OCaml/00____piscine_ocaml/rush01.en.pdf
# END- ./42_Russia/00_Projects/09_OCaml/00____piscine_ocaml/d00.en.pdf
# END- ./42_Russia/00_Projects/09_OCaml/00____piscine_ocaml/d09.en.pdf
# END- ./42_Russia/00_Projects/09_OCaml/00____piscine_ocaml/d05.en.pdf
# END- ./42_Russia/00_Projects/09_OCaml/00____piscine_ocaml/d07.en.pdf
# END- ./42_Russia/00_Projects/09_OCaml/00____piscine_ocaml/d03.en.pdf
# END- ./42_Russia/00_Projects/09_OCaml/00____piscine_ocaml/d01.en.pdf
# END- ./42_Russia/00_Projects/09_OCaml/00____piscine_ocaml/rush00.en.pdf
# END- ./42_Russia/00_Projects/09_OCaml/01____h42n42/h42n42.pdf
# END- ./42_Russia/00_Projects/09_OCaml/01____ft_ality/ft_ality.pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/01_3__ft_ssl_rsa/ft_ssl_rsa_(old).pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/01_3__ft_ssl_rsa/ft_ssl_rsa_(new).pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/03____lem_in/lem_in.pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/08____krpsim/krpsim.pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/05_3__expert_system/expert_system.pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/00____ft_printf/ft_printf_(new).pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/00____ft_printf/ft_printf(old).pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/05_1__computorv1/computorv1_(old).pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/05_1__computorv1/computorv1_(new).pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/05_2__computorv2/computorv2_(new).pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/05_2__computorv2/computorv2_(old).pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/01_1__ft_ssl_md5/ft_ssl_md5.pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/05_3__n-puzzle/n-puzzle.pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/06_3__multilayer_perceptron/multilayer_perceptron.pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/07____rubik/rubik_(new).pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/07____rubik/rubik_(old).pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/04_0__mod1/mod1.pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/09____gomoku/gomoku.pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/02____push_swap/push_swap.pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/04_1___corewar/corewar_(new).pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/04_1___corewar/corewar_(old).pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/04_1___corewar/resources_corewar.pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/06_2__dslr/DatascienceLogisticRegression.pdf
# END- ./42_Russia/00_Projects/02_Algorithmic/06_3__total-perspective-vortex/total-perspective-vortex.pdf
# END- ./42_Russia/00_Projects/02_Algorithmic
pdf
# END- ./42_Russia/00_Projects/01_Unix/12_2_9____kfs-x/kfs_10.pdf
# END- ./42_Russia/00_Projects/01_Unix/10_2_0____snow_crash/snow-crash.pdf
# END- ./42_Russia/00_Projects/01_Unix/05________malloc/ft_malloc.pdf
# END- ./42_Russia/00_Projects/01_Unix/10_1_2____root_me_cracking/root_me_cracking.pdf
# END- ./42_Russia/00_Projects/01_Unix/12_2_2____kfs-3/kfs_3.pdf
# END- ./42_Russia/00_Projects/01_Unix/12_2_3____kfs-4/kfs-4.pdf
# END- ./42_Russia/00_Projects/01_Unix/09_1_2____ft_nmap/ft_nmap.pdf
# END- ./42_Russia/00_Projects/01_Unix/12_1_2____Process_and_Memory/lk_process_and_memory.pdf
# END- ./42_Russia/00_Projects/01_Unix/04_0______taskmaster/taskmaster.pdf
# END- ./42_Russia/00_Projects/01_Unix/11_3_4____death/death.pdf
# END- ./42_Russia/00_Projects/01_Unix/12_2_4____kfs-5/kfs_5.pdf
# END- ./42_Russia/00_Projects/01_Unix/09_1_1____ft_traceroute/ft_traceroute.pdf
# END- ./42_Russia/00_Projects/01_Unix/11_3_2____pestilence/pestilence.pdf
# END- ./42_Russia/00_Projects/01_Unix/09_4_1____durex/durex_Sep.pdf
# END- ./42_Russia/00_Projects/01_Unix/12_2_6____kfs-7/kfs_7.pdf
# END- ./42_Russia/00_Projects/01_Unix/10_1_2____root_me_app_systeme/root_me_app_systeme.pdf
# END- ./42_Russia/00_Projects/01_Unix/04_1______42sh/42sh.pdf
# END- ./42_Russia/00_Projects/01_Unix/09_0______irc/irc.pdf
# END- ./42_Russia/00_Projects/01_Unix/09_4_0____matt_daemon/matt-daemon.pdf
# END- ./42_Russia/00_Projects/01_Unix/12_1_0_1__userspace_digressions/userspace_digressions_Sep_21_20.pdf
# END- ./42_Russia/00_Projects/01_Unix/12_1_1____Driver_and_Interrupts_OR_Keyboard/drivers-and-interrupts.pdf
# END- ./42_Russia/00_Projects/01_Unix/00________ft_ls/ft_ls.pdf
# END- ./42_Russia/00_Projects/01_Unix/12_2_7____kfs-8/kfs_8.pdf
# END- ./42_Russia/00_Projects/01_Unix/10_2_1____rain-fall/rainfall.fr.pdf
# END- ./42_Russia/00_Projects/01_Unix/10_2_1____rain-fall/rainfall.en.pdf
# END- ./42_Russia/00_Projects/01_Unix/09_0______ft_p/ft_p.pdf
# END- ./42_Russia/00_Projects/10_Ai/02____reverse_game_of_life/reverse_game_of_life.pdf
# END- ./42_Russia/00_Projects/10_Ai/01____ft_sommelier/ft_sommelier.pdf
# END- ./42_Russia/00_Projects/10_Ai/00____walking_marvin/walking-marvin.pdf
# END- ./42_Russia/00_Projects/13_Open_Projects/Open Project - Define your Subject/Open Project - Define your Subject_Sep_21_20.pdf
# END- ./42_Russia/00_Projects/13_Open_Projects/Open Project - Complete the project/Open Project - Complete the project_Sep_21_20.pdf
# END- ./42_Russia/00_Projects/13_Open_Projects/Open Project/Open Project_Sep_21_20.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/02_2__avaj-launcher/avaj-launcher.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/02_1__ft_hangouts/ft_hangouts.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/01____swifty-companion/swifty-companion.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/05____music-room/music-room_Sep_21_20.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/03____swingy/swingy.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/04____fixme/fixme.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/02_0__swifty-protein/swifty-protein.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/00____piscine_swift_ios/d08.en.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/00____piscine_swift_ios/d04.en.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/00____piscine_swift_ios/d06.en.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/00____piscine_swift_ios/d02.en.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/00____piscine_swift_ios/rush01.en.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/00____piscine_swift_ios/d00.en.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/00____piscine_swift_ios/d09.en.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/00____piscine_swift_ios/d05.en.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/00____piscine_swift_ios/d07.en.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/00____piscine_swift_ios/d03.en.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/00____piscine_swift_ios/d01.en.pdf
# END- ./42_Russia/00_Projects/06_Android-iOS/00____piscine_swift_ios/rush00.en.pdf

# %%
len(pdf_files)
# Out:
# 232

# %% [markdown]
# END- ./42_Russia/00_Projects/07_CPP/06____nibbler/nibbler.pdf

# %% [markdown]
# ## まとめ
# ※Adobe Acrobat Readerで閲覧してください。ブラウザ経由だと注釈が文字化けします。

# %% [markdown]
# ## 参考サイト
# [mima3/pdf_translate](https://github.com/mima3/pdf_translate)
#
# [UKPLab/EasyNMT](https://github.com/UKPLab/EasyNMT)
#
# [PythonでPDFのレイアウトを維持したまま翻訳してみる](https://qiita.com/mima_ita/items/3f698050196d4af3a46d)
#
# [yta-git/pdf_translate](https://github.com/yta-git/pdf_translate)
#
# [【python】googletransの『AttributeError: 'NoneType' object has no attribute 'group'』対策](https://qiita.com/_yushuu/items/83c51e29771530646659)

# %% [markdown]
# ## エラー集
